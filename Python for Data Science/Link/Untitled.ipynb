# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r')df=pd.read_csv(r'

# %%
import plotly.express as px

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
iris=px.data.iris()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
fig =px.scatter(iris,x='sepal_width' ,y= 'sepal_length', size ='petal length')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fig =px.scatter(iris , x='sepal_width' ,y= 'sepal_length', size ='petal length')
#       2 fig.show()
#
# File D:\Python\Lib\site-packages\plotly\express\_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.scatterplot(x='sepal_width' ,y= 'sepal_length',data=iris, hue='species', size='petal_length',sizes=[20,200])
# Out:
# C:\Users\Nitish Kumar\AppData\Local\Temp\ipykernel_24220\202642663.py:1: UserWarning:
# The sizes list has fewer values (2) than needed (43) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='sepal_width' ,y= 'sepal_length',data=iris, hue='species', size='petal_length',sizes=[20,200])
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>
