# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=([37,31,34,45,34,34,12,56,67,87,98,67],[1,2,3,4,5,6,7,8,9],[23,34,45,45,34,23,12,23,56,78])
plt.boxplot(x ,patch_artist = False,notch =False)
plt.show()
