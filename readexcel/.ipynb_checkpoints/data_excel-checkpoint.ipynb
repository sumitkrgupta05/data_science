# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Reading data from MS Excel to Jupyter

# %%
import pandas as pd
dataset =pd.read_excel("IRQA_Vessel_Plant_Story04_Apr_2024_15_53.xlsx")
dataset
# Out:
#      Vessel Plant Story Vessel Plant Story.1       Vessel Plant Story.2  \
# 0            From Date:          01-Jan-2023                   To Date:
# 1                   NaN                  NaN                        NaN
# 2                 PLANT               BASKET                      GRADE
# 3                   TSJ                  HCC                   Lampunut
# 4                   TSJ                  HCC                    TAHMOOR
# ...                 ...                  ...                        ...
# 4376                TSJ                 WEAK  POITREL PCI (23% VM) WEAK
# 4377                HMC                 WEAK                    IP EAST
# 4378                HMC                 WEAK                    IP EAST
# 4379                TSK                 WEAK       Capricorn PCI (Weak)
# 4380                TSJ                 WEAK              SW PCI (WEAK)
#
#      Vessel Plant Story.3 Vessel Plant Story.4 Vessel Plant Story.5  \
# ...

# %%
# maxmium row that can be printed
pd.get_option("display.max_columns")
# Out:
# 20

# %%
# set to print all the column
pd.set_option("display.max_columns",None)
# dataset

# %%
# set to print 20 column
pd.set_option("display.max_columns",20)
# dataset
